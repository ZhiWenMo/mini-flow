# %%
import numpy as np

# %% [markdown]
# ## Create a base case of class
#
# - method:**__init__** to initilize all the properties, **forward** to compute the values, **backward** to propagate the error and compute the gradients

# %%
class Node(object):
    def __init__(self,inbound_nodes = []):
        #a list of input nodes to this node
        self.inbound_nodes = inbound_nodes
        # the output nodes of this node
        self.outbound_nodes = []
        #the eventual of this node set bu forward method
        self.value = None
        #key is input nodes,value is patial of this node with respect to input nodes
        self.gradients = {}
        #set input node's outbound node to this node
        for n in self.inbound_nodes:
            n.outbound_nodes.append(self)
            
    def forward(self):
        #every subclass need this method
        raise NotImplementedError
        
    def backward(self):
        #every subcalss need this method
        raise NotImplementedError

# %% [markdown]
# ## Input node
# - The **Input** node has no inboud nodes
# - Take the gradients directly from the outbound nodes

# %%
class Input(Node):
    def __init__(self):
        #initialize all properties using base class
        #self.value is set during `topological_sort` later
        Node.__init__(self)
    
    def forward(self):
        pass
    
    def backward(self):
        #The Input node has no input so the the key self set to 0
        self.gradients = {self:0}
        #weight and bias may be input, get their gradients from their outbound nodes
        for n in self.outbound_nodes:
            self.gradients[self] += n.gradients[self]

# %% [markdown]
# ## Linear node
# - inbound nodes are X(training data),weights and bias
# - **forward** calculate the value by numpy
# - **backward** use the gradient cost from the outbound nodes to calculate the partials with respect to inbound nodes

# %%
class Linear(Node):
    def __init__(self,X,W,b):
        #set weights bias as inboud nodes
        Node.__init__(self,[X,W,b])
        
    def forward(self):
        X = self.inbound_nodes[0].value
        W = self.inbound_nodes[1].value
        b = self.inbound_nodes[2].value
        
        self.value = np.dot(X,W) + b
        
    def backward(self):
        self.gradients = {n:np.zeros_like(n.value) for n in self.inbound_nodes}
        
        for n in self.outbound_nodes:
            grad_cost = n.gradients[self]
            self.gradients[self.inbound_nodes[0]] += grad_cost@self.inbound_nodes[1].value.T
            self.gradients[self.inbound_nodes[1]] += self.inbound_nodes[0].value.T@grad_cost
            self.gradients[self.inbound_nodes[2]] += np.sum(grad_cost,axis=0,keepdims=False)

# %% [markdown]
# ## Sigmoid node
# - **forward** apply the sigmoid func to the input nodes
# - **backward** use the gradient cost from the outbound nodes to calculate the partials with respect to inbound nodes

# %%
class Sigmoid(Node):
    def __init__(self,node):
        Node.__init__(self,[node])
        
    def _sigmoid(self,x):
        return 1./(1.+np.exp(-x))
    
    def forward(self):
        x = self.inbound_nodes[0].value
        self.value = self._sigmoid(x)
        
    def backward(self):
        self.gradients = {n:np.zeros_like(n.value) for n in self.inbound_nodes}
        for n in self.outbound_nodes:
            grad_cost = n.gradients[self]
            sigmoid = self.value
            self.gradients[self.inbound_nodes[0]] += grad_cost * sigmoid * (1-sigmoid)

# %% [markdown]
# ## MSE node
# - **forward** calculate the mean of squared errors
# - **backward** calculate the partial with respect to the inbound nodes

# %%
class MSE(Node):
    def __init__(self,y,a):
        Node.__init__(self,[y,a])
        
    def forward(self):
        y = self.inbound_nodes[0].value.reshape(-1,1)
        
        a= self.inbound_nodes[1].value.reshape(-1,1)
        
        assert y.shape[0] == a.shape[0]
        
        self.m=self.inbound_nodes[0].value.shape[0]
        
        self.diff = y - a
        
        self.value = np.mean(self.diff**2)
        
    def backward(self):
        self.gradients[self.inbound_nodes[0]] = (2/self.m) * self.diff
        self.gradients[self.inbound_nodes[1]] = (-2/self.m) * self.diff

# %% [markdown]
# ## topological sort
# - create a graph according to the properties of the nodes
# - sort the nodes in topological order using Kahn's Algorithm

# %%
def topological_sort(feed_dict):
    """
    Sort the nodes in topological order using Kahn's Algorithm.

    `feed_dict`: A dictionary where the key is a `Input` Node and the value is the respective value feed to that Node.

    Returns a list of sorted nodes.
    """

    input_nodes = [n for n in feed_dict.keys()]

    G = {}
    nodes = [n for n in input_nodes]
    while len(nodes) > 0:
        n = nodes.pop(0)
        if n not in G:
            G[n] = {'in': set(), 'out': set()}
        for m in n.outbound_nodes:
            if m not in G:
                G[m] = {'in': set(), 'out': set()}
            G[n]['out'].add(m)
            G[m]['in'].add(n)
            nodes.append(m)

    L = []
    S = set(input_nodes)
    while len(S) > 0:
        n = S.pop()

        if isinstance(n, Input):
            n.value = feed_dict[n]

        L.append(n)
        for m in n.outbound_nodes:
            G[n]['out'].remove(m)
            G[m]['in'].remove(n)
            # if no other incoming edges add to S
            if len(G[m]['in']) == 0:
                S.add(m)
    return L

# %% [markdown]
# ## use foward and backward method according to the topological sort

# %%
def forward_and_backward(graph):
    # Forward pass
    for n in graph:
        n.forward()


    # Backward pass
    for n in graph[::-1]:
        n.backward()

# %% [markdown]
# ## SGD to update weight and bias

# %%
def sgd_update(trainables, learning_rate=1e-2):
    """
    Updates the value of each trainable with SGD.

    Arguments:

        `trainables`: A list of `Input` Nodes representing weights/biases.
        `learning_rate`: The learning rate.
    """
    # Performs SGD
    #
    # Loop over the trainables
    for t in trainables:
        # Change the trainable's value by subtracting the learning rate
        # multiplied by the partial of the cost with respect to this
        # trainable.
        partial = t.gradients[t]
        t.value -= learning_rate * partial

# %% [markdown]
# ## Predict the Boston house price using miniflow

# %%
"""
Have fun with the number of epochs!

Be warned that if you increase them too much,
the VM will time out :)
"""

import numpy as np
from sklearn.datasets import load_boston
from sklearn.utils import shuffle, resample
#from miniflow import *

# Load data
data = load_boston()
X_ = data['data']
y_ = data['target']

# Normalize data
X_ = (X_ - np.mean(X_, axis=0)) / np.std(X_, axis=0)

n_features = X_.shape[1]
n_hidden = 10
W1_ = np.random.randn(n_features, n_hidden)
b1_ = np.zeros(n_hidden)
W2_ = np.random.randn(n_hidden, 1)
b2_ = np.zeros(1)

# Neural network
X, y = Input(), Input()
W1, b1 = Input(), Input()
W2, b2 = Input(), Input()

l1 = Linear(X, W1, b1)
s1 = Sigmoid(l1)
l2 = Linear(s1, W2, b2)
cost = MSE(y, l2)

feed_dict = {
    X: X_,
    y: y_,
    W1: W1_,
    b1: b1_,
    W2: W2_,
    b2: b2_
}

epochs = 1000
# Total number of examples
m = X_.shape[0]
batch_size = 11
steps_per_epoch = m // batch_size

graph = topological_sort(feed_dict)
trainables = [W1, b1, W2, b2]

print("Total number of examples = {}".format(m))

# Step 4
for i in range(epochs):
    loss = 0
    for j in range(steps_per_epoch):
        # Step 1
        # Randomly sample a batch of examples
        X_batch, y_batch = resample(X_, y_, n_samples=batch_size)

        # Reset value of X and y Inputs
        X.value = X_batch
        y.value = y_batch

        # Step 2
        forward_and_backward(graph)

        # Step 3
        sgd_update(trainables)

        loss += graph[-1].value
        

    print("Epoch: {}, Loss: {:.3f}".format(i+1, loss/steps_per_epoch))
# Out:
# Total number of examples = 506
# Epoch: 1, Loss: 133.238
# Epoch: 2, Loss: 31.995
# Epoch: 3, Loss: 23.921
# Epoch: 4, Loss: 27.718
# Epoch: 5, Loss: 18.915
# Epoch: 6, Loss: 21.028
# Epoch: 7, Loss: 19.623
# Epoch: 8, Loss: 18.517
# Epoch: 9, Loss: 14.931
# Epoch: 10, Loss: 13.225
# Epoch: 11, Loss: 15.511
# Epoch: 12, Loss: 10.678
# Epoch: 13, Loss: 9.544
# Epoch: 14, Loss: 13.647
# Epoch: 15, Loss: 12.702
# Epoch: 16, Loss: 10.774
# Epoch: 17, Loss: 13.872
# Epoch: 18, Loss: 12.359
# Epoch: 19, Loss: 9.636
# Epoch: 20, Loss: 12.539
# Epoch: 21, Loss: 10.275
# Epoch: 22, Loss: 11.044
# Epoch: 23, Loss: 11.919
# Epoch: 24, Loss: 10.690
# Epoch: 25, Loss: 10.784
# Epoch: 26, Loss: 10.346
# Epoch: 27, Loss: 8.929
# Epoch: 28, Loss: 9.555
# Epoch: 29, Loss: 10.761
# Epoch: 30, Loss: 8.754
# Epoch: 31, Loss: 9.735
# Epoch: 32, Loss: 9.734
# Epoch: 33, Loss: 10.091
# Epoch: 34, Loss: 9.159
# Epoch: 35, Loss: 12.140
# Epoch: 36, Loss: 9.680
# Epoch: 37, Loss: 8.967
# Epoch: 38, Loss: 7.741
# Epoch: 39, Loss: 9.547
# Epoch: 40, Loss: 8.276
# Epoch: 41, Loss: 9.580
# Epoch: 42, Loss: 8.851
# Epoch: 43, Loss: 8.648
# Epoch: 44, Loss: 8.964
# Epoch: 45, Loss: 8.837
# Epoch: 46, Loss: 10.418
# Epoch: 47, Loss: 7.878
# Epoch: 48, Loss: 6.970
# Epoch: 49, Loss: 9.837
# Epoch: 50, Loss: 8.177
# Epoch: 51, Loss: 9.176
# Epoch: 52, Loss: 7.425
# Epoch: 53, Loss: 8.125
# Epoch: 54, Loss: 6.587
# Epoch: 55, Loss: 8.943
# Epoch: 56, Loss: 8.267
# Epoch: 57, Loss: 7.697
# Epoch: 58, Loss: 6.297
# Epoch: 59, Loss: 7.554
# Epoch: 60, Loss: 8.382
# Epoch: 61, Loss: 6.631
# Epoch: 62, Loss: 8.320
# Epoch: 63, Loss: 7.946
# Epoch: 64, Loss: 8.967
# Epoch: 65, Loss: 6.338
# Epoch: 66, Loss: 7.467
# Epoch: 67, Loss: 7.194
# Epoch: 68, Loss: 10.479
# Epoch: 69, Loss: 7.814
# Epoch: 70, Loss: 7.130
# Epoch: 71, Loss: 6.274
# Epoch: 72, Loss: 7.158
# Epoch: 73, Loss: 6.491
# Epoch: 74, Loss: 6.300
# Epoch: 75, Loss: 6.628
# Epoch: 76, Loss: 7.656
# Epoch: 77, Loss: 7.408
# Epoch: 78, Loss: 6.633
# Epoch: 79, Loss: 6.787
# Epoch: 80, Loss: 6.490
# Epoch: 81, Loss: 7.405
# Epoch: 82, Loss: 6.025
# Epoch: 83, Loss: 6.837
# Epoch: 84, Loss: 6.122
# Epoch: 85, Loss: 6.882
# Epoch: 86, Loss: 6.180
# Epoch: 87, Loss: 7.083
# Epoch: 88, Loss: 7.870
# Epoch: 89, Loss: 5.680
# Epoch: 90, Loss: 7.010
# Epoch: 91, Loss: 6.762
# Epoch: 92, Loss: 6.724
# Epoch: 93, Loss: 5.805
# Epoch: 94, Loss: 5.948
# Epoch: 95, Loss: 7.335
# Epoch: 96, Loss: 6.738
# Epoch: 97, Loss: 6.556
# Epoch: 98, Loss: 7.263
# Epoch: 99, Loss: 6.897
# Epoch: 100, Loss: 6.276
# Epoch: 101, Loss: 5.787
# Epoch: 102, Loss: 6.356
# Epoch: 103, Loss: 7.029
# Epoch: 104, Loss: 6.031
# Epoch: 105, Loss: 6.011
# Epoch: 106, Loss: 6.364
# Epoch: 107, Loss: 6.051
# Epoch: 108, Loss: 5.445
# Epoch: 109, Loss: 6.157
# Epoch: 110, Loss: 6.373
# Epoch: 111, Loss: 5.884
# Epoch: 112, Loss: 6.376
# Epoch: 113, Loss: 5.254
# Epoch: 114, Loss: 5.053
# Epoch: 115, Loss: 5.787
# Epoch: 116, Loss: 4.868
# Epoch: 117, Loss: 5.235
# Epoch: 118, Loss: 5.094
# Epoch: 119, Loss: 5.354
# Epoch: 120, Loss: 5.781
# Epoch: 121, Loss: 6.208
# Epoch: 122, Loss: 5.419
# Epoch: 123, Loss: 6.313
# Epoch: 124, Loss: 5.891
# Epoch: 125, Loss: 4.636
# Epoch: 126, Loss: 5.861
# Epoch: 127, Loss: 4.678
# Epoch: 128, Loss: 5.436
# Epoch: 129, Loss: 5.280
# Epoch: 130, Loss: 5.430
# Epoch: 131, Loss: 6.084
# Epoch: 132, Loss: 5.117
# Epoch: 133, Loss: 4.691
# Epoch: 134, Loss: 4.190
# Epoch: 135, Loss: 5.651
# Epoch: 136, Loss: 4.279
# Epoch: 137, Loss: 5.742
# Epoch: 138, Loss: 4.579
# Epoch: 139, Loss: 5.110
# Epoch: 140, Loss: 5.078
# Epoch: 141, Loss: 5.055
# Epoch: 142, Loss: 4.529
# Epoch: 143, Loss: 4.418
# Epoch: 144, Loss: 6.337
# Epoch: 145, Loss: 4.919
# Epoch: 146, Loss: 5.347
# Epoch: 147, Loss: 5.029
# Epoch: 148, Loss: 6.122
# Epoch: 149, Loss: 5.406
# Epoch: 150, Loss: 5.198
# Epoch: 151, Loss: 4.849
# Epoch: 152, Loss: 4.932
# Epoch: 153, Loss: 5.096
# Epoch: 154, Loss: 4.923
# Epoch: 155, Loss: 4.711
# Epoch: 156, Loss: 4.930
# Epoch: 157, Loss: 5.273
# Epoch: 158, Loss: 4.503
# Epoch: 159, Loss: 5.000
# Epoch: 160, Loss: 5.389
# Epoch: 161, Loss: 4.958
# Epoch: 162, Loss: 4.465
# Epoch: 163, Loss: 5.117
# Epoch: 164, Loss: 5.132
# Epoch: 165, Loss: 5.052
# Epoch: 166, Loss: 5.490
# Epoch: 167, Loss: 5.052
# Epoch: 168, Loss: 4.382
# Epoch: 169, Loss: 5.291
# Epoch: 170, Loss: 4.253
# Epoch: 171, Loss: 5.838
# Epoch: 172, Loss: 5.333
# Epoch: 173, Loss: 5.370
# Epoch: 174, Loss: 4.240
# Epoch: 175, Loss: 4.372
# Epoch: 176, Loss: 5.128
# Epoch: 177, Loss: 4.169
# Epoch: 178, Loss: 4.603
# Epoch: 179, Loss: 4.537
# Epoch: 180, Loss: 5.206
# Epoch: 181, Loss: 5.360
# Epoch: 182, Loss: 4.937
# Epoch: 183, Loss: 4.444
# Epoch: 184, Loss: 4.307
# Epoch: 185, Loss: 5.054
# Epoch: 186, Loss: 4.086
# Epoch: 187, Loss: 4.007
# Epoch: 188, Loss: 4.832
# Epoch: 189, Loss: 4.425
# Epoch: 190, Loss: 4.770
# Epoch: 191, Loss: 4.694
# Epoch: 192, Loss: 5.460
# Epoch: 193, Loss: 4.341
# Epoch: 194, Loss: 4.889
# Epoch: 195, Loss: 4.995
# Epoch: 196, Loss: 4.982
# Epoch: 197, Loss: 4.631
# Epoch: 198, Loss: 4.353
# Epoch: 199, Loss: 4.416
# Epoch: 200, Loss: 4.863
# Epoch: 201, Loss: 4.053
# Epoch: 202, Loss: 4.380
# Epoch: 203, Loss: 4.669
# Epoch: 204, Loss: 4.360
# Epoch: 205, Loss: 4.247
# Epoch: 206, Loss: 4.548
# Epoch: 207, Loss: 4.406
# Epoch: 208, Loss: 4.292
# Epoch: 209, Loss: 5.627
# Epoch: 210, Loss: 4.960
# Epoch: 211, Loss: 5.454
# Epoch: 212, Loss: 5.058
# Epoch: 213, Loss: 4.573
# Epoch: 214, Loss: 4.460
# Epoch: 215, Loss: 4.326
# Epoch: 216, Loss: 4.759
# Epoch: 217, Loss: 4.135
# Epoch: 218, Loss: 4.595
# Epoch: 219, Loss: 4.611
# Epoch: 220, Loss: 4.473
# Epoch: 221, Loss: 3.882
# Epoch: 222, Loss: 4.831
# Epoch: 223, Loss: 4.972
# Epoch: 224, Loss: 3.991
# Epoch: 225, Loss: 4.309
# Epoch: 226, Loss: 4.558
# Epoch: 227, Loss: 5.356
# Epoch: 228, Loss: 4.298
# Epoch: 229, Loss: 4.216
# Epoch: 230, Loss: 4.411
# Epoch: 231, Loss: 4.114
# Epoch: 232, Loss: 4.846
# Epoch: 233, Loss: 4.545
# Epoch: 234, Loss: 4.453
# Epoch: 235, Loss: 4.162
# Epoch: 236, Loss: 4.686
# Epoch: 237, Loss: 5.028
# Epoch: 238, Loss: 3.616
# Epoch: 239, Loss: 4.752
# Epoch: 240, Loss: 4.490
# Epoch: 241, Loss: 3.680
# Epoch: 242, Loss: 3.936
# Epoch: 243, Loss: 4.138
# Epoch: 244, Loss: 4.741
# Epoch: 245, Loss: 4.547
# Epoch: 246, Loss: 4.505
# Epoch: 247, Loss: 4.203
# Epoch: 248, Loss: 4.854
# Epoch: 249, Loss: 4.457
# Epoch: 250, Loss: 4.248
# Epoch: 251, Loss: 4.344
# Epoch: 252, Loss: 4.278
# Epoch: 253, Loss: 4.515
# Epoch: 254, Loss: 4.836
# Epoch: 255, Loss: 4.205
# Epoch: 256, Loss: 4.266
# Epoch: 257, Loss: 4.162
# Epoch: 258, Loss: 4.349
# Epoch: 259, Loss: 4.259
# Epoch: 260, Loss: 4.115
# Epoch: 261, Loss: 3.628
# Epoch: 262, Loss: 4.676
# Epoch: 263, Loss: 3.862
# Epoch: 264, Loss: 4.260
# Epoch: 265, Loss: 3.777
# Epoch: 266, Loss: 4.263
# Epoch: 267, Loss: 4.257
# Epoch: 268, Loss: 3.879
# Epoch: 269, Loss: 3.544
# Epoch: 270, Loss: 3.869
# Epoch: 271, Loss: 3.612
# Epoch: 272, Loss: 3.650
# Epoch: 273, Loss: 4.191
# Epoch: 274, Loss: 4.625
# Epoch: 275, Loss: 4.082
# Epoch: 276, Loss: 4.628
# Epoch: 277, Loss: 4.960
# Epoch: 278, Loss: 4.101
# Epoch: 279, Loss: 4.266
# Epoch: 280, Loss: 4.085
# Epoch: 281, Loss: 3.922
# Epoch: 282, Loss: 3.966
# Epoch: 283, Loss: 4.158
# Epoch: 284, Loss: 3.719
# Epoch: 285, Loss: 4.161
# Epoch: 286, Loss: 3.808
# Epoch: 287, Loss: 4.028
# Epoch: 288, Loss: 3.765
# Epoch: 289, Loss: 4.028
# Epoch: 290, Loss: 3.860
# Epoch: 291, Loss: 3.955
# Epoch: 292, Loss: 4.485
# Epoch: 293, Loss: 3.897
# Epoch: 294, Loss: 4.064
# Epoch: 295, Loss: 3.843
# Epoch: 296, Loss: 3.576
# Epoch: 297, Loss: 3.372
# Epoch: 298, Loss: 3.790
# Epoch: 299, Loss: 3.636
# Epoch: 300, Loss: 4.160
# Epoch: 301, Loss: 3.818
# Epoch: 302, Loss: 3.600
# Epoch: 303, Loss: 3.819
# Epoch: 304, Loss: 3.509
# Epoch: 305, Loss: 4.088
# Epoch: 306, Loss: 4.084
# Epoch: 307, Loss: 3.593
# Epoch: 308, Loss: 3.882
# Epoch: 309, Loss: 4.071
# Epoch: 310, Loss: 3.699
# Epoch: 311, Loss: 3.459
# Epoch: 312, Loss: 4.322
# Epoch: 313, Loss: 3.702
# Epoch: 314, Loss: 3.787
# Epoch: 315, Loss: 3.936
# Epoch: 316, Loss: 3.554
# Epoch: 317, Loss: 3.462
# Epoch: 318, Loss: 4.067
# Epoch: 319, Loss: 4.439
# Epoch: 320, Loss: 3.462
# Epoch: 321, Loss: 4.078
# Epoch: 322, Loss: 4.122
# Epoch: 323, Loss: 3.770
# Epoch: 324, Loss: 4.158
# Epoch: 325, Loss: 4.141
# Epoch: 326, Loss: 4.029
# Epoch: 327, Loss: 4.156
# Epoch: 328, Loss: 3.764
# Epoch: 329, Loss: 3.664
# Epoch: 330, Loss: 3.838
# Epoch: 331, Loss: 4.022
# Epoch: 332, Loss: 4.078
# Epoch: 333, Loss: 3.574
# Epoch: 334, Loss: 3.689
# Epoch: 335, Loss: 3.371
# Epoch: 336, Loss: 3.501
# Epoch: 337, Loss: 3.697
# Epoch: 338, Loss: 3.122
# Epoch: 339, Loss: 3.888
# Epoch: 340, Loss: 4.073
# Epoch: 341, Loss: 4.279
# Epoch: 342, Loss: 4.332
# Epoch: 343, Loss: 3.768
# Epoch: 344, Loss: 3.440
# Epoch: 345, Loss: 3.931
# Epoch: 346, Loss: 4.342
# Epoch: 347, Loss: 3.804
# Epoch: 348, Loss: 3.287
# Epoch: 349, Loss: 3.981
# Epoch: 350, Loss: 3.904
# Epoch: 351, Loss: 4.086
# Epoch: 352, Loss: 3.795
# Epoch: 353, Loss: 3.882
# Epoch: 354, Loss: 3.135
# Epoch: 355, Loss: 4.158
# Epoch: 356, Loss: 4.051
# Epoch: 357, Loss: 3.544
# Epoch: 358, Loss: 3.701
# Epoch: 359, Loss: 3.798
# Epoch: 360, Loss: 3.732
# Epoch: 361, Loss: 3.825
# Epoch: 362, Loss: 3.528
# Epoch: 363, Loss: 3.670
# Epoch: 364, Loss: 3.649
# Epoch: 365, Loss: 3.244
# Epoch: 366, Loss: 3.669
# Epoch: 367, Loss: 3.908
# Epoch: 368, Loss: 3.559
# Epoch: 369, Loss: 3.521
# Epoch: 370, Loss: 4.102
# Epoch: 371, Loss: 3.421
# Epoch: 372, Loss: 3.578
# Epoch: 373, Loss: 3.147
# Epoch: 374, Loss: 4.013
# Epoch: 375, Loss: 3.735
# Epoch: 376, Loss: 4.038
# Epoch: 377, Loss: 3.611
# Epoch: 378, Loss: 3.615
# Epoch: 379, Loss: 3.519
# Epoch: 380, Loss: 3.740
# Epoch: 381, Loss: 3.222
# Epoch: 382, Loss: 3.929
# Epoch: 383, Loss: 4.039
# Epoch: 384, Loss: 4.075
# Epoch: 385, Loss: 3.804
# Epoch: 386, Loss: 4.082
# Epoch: 387, Loss: 3.444
# Epoch: 388, Loss: 3.807
# Epoch: 389, Loss: 3.410
# Epoch: 390, Loss: 3.199
# Epoch: 391, Loss: 3.736
# Epoch: 392, Loss: 3.798
# Epoch: 393, Loss: 3.714
# Epoch: 394, Loss: 3.252
# Epoch: 395, Loss: 3.807
# Epoch: 396, Loss: 3.645
# Epoch: 397, Loss: 3.398
# Epoch: 398, Loss: 3.523
# Epoch: 399, Loss: 3.949
# Epoch: 400, Loss: 4.017
# Epoch: 401, Loss: 3.346
# Epoch: 402, Loss: 3.926
# Epoch: 403, Loss: 4.019
# Epoch: 404, Loss: 3.720
# Epoch: 405, Loss: 3.711
# Epoch: 406, Loss: 3.682
# Epoch: 407, Loss: 4.204
# Epoch: 408, Loss: 3.351
# Epoch: 409, Loss: 4.276
# Epoch: 410, Loss: 3.521
# Epoch: 411, Loss: 3.763
# Epoch: 412, Loss: 3.556
# Epoch: 413, Loss: 3.848
# Epoch: 414, Loss: 3.313
# Epoch: 415, Loss: 3.788
# Epoch: 416, Loss: 3.466
# Epoch: 417, Loss: 4.089
# Epoch: 418, Loss: 3.589
# Epoch: 419, Loss: 3.418
# Epoch: 420, Loss: 3.407
# Epoch: 421, Loss: 3.357
# Epoch: 422, Loss: 3.566
# Epoch: 423, Loss: 3.893
# Epoch: 424, Loss: 3.750
# Epoch: 425, Loss: 3.292
# Epoch: 426, Loss: 3.958
# Epoch: 427, Loss: 3.820
# Epoch: 428, Loss: 3.822
# Epoch: 429, Loss: 3.492
# Epoch: 430, Loss: 3.345
# Epoch: 431, Loss: 3.685
# Epoch: 432, Loss: 3.065
# Epoch: 433, Loss: 3.473
# Epoch: 434, Loss: 3.942
# Epoch: 435, Loss: 4.297
# Epoch: 436, Loss: 3.635
# Epoch: 437, Loss: 4.121
# Epoch: 438, Loss: 3.529
# Epoch: 439, Loss: 3.835
# Epoch: 440, Loss: 3.343
# Epoch: 441, Loss: 3.488
# Epoch: 442, Loss: 3.472
# Epoch: 443, Loss: 3.330
# Epoch: 444, Loss: 3.532
# Epoch: 445, Loss: 4.071
# Epoch: 446, Loss: 3.409
# Epoch: 447, Loss: 3.619
# Epoch: 448, Loss: 3.683
# Epoch: 449, Loss: 3.041
# Epoch: 450, Loss: 3.448
# Epoch: 451, Loss: 3.755
# Epoch: 452, Loss: 3.463
# Epoch: 453, Loss: 3.291
# Epoch: 454, Loss: 3.829
# Epoch: 455, Loss: 3.943
# Epoch: 456, Loss: 3.832
# Epoch: 457, Loss: 3.716
# Epoch: 458, Loss: 3.506
# Epoch: 459, Loss: 3.437
# Epoch: 460, Loss: 3.433
# Epoch: 461, Loss: 3.608
# Epoch: 462, Loss: 3.458
# Epoch: 463, Loss: 3.716
# Epoch: 464, Loss: 3.519
# Epoch: 465, Loss: 3.653
# Epoch: 466, Loss: 3.821
# Epoch: 467, Loss: 4.059
# Epoch: 468, Loss: 4.022
# Epoch: 469, Loss: 3.396
# Epoch: 470, Loss: 3.166
# Epoch: 471, Loss: 3.272
# Epoch: 472, Loss: 3.959
# Epoch: 473, Loss: 3.392
# Epoch: 474, Loss: 3.751
# Epoch: 475, Loss: 3.065
# Epoch: 476, Loss: 4.088
# Epoch: 477, Loss: 3.421
# Epoch: 478, Loss: 4.249
# Epoch: 479, Loss: 3.294
# Epoch: 480, Loss: 3.467
# Epoch: 481, Loss: 3.585
# Epoch: 482, Loss: 3.088
# Epoch: 483, Loss: 3.781
# Epoch: 484, Loss: 3.282
# Epoch: 485, Loss: 3.327
# Epoch: 486, Loss: 3.653
# Epoch: 487, Loss: 3.815
# Epoch: 488, Loss: 3.080
# Epoch: 489, Loss: 3.639
# Epoch: 490, Loss: 3.446
# Epoch: 491, Loss: 3.723
# Epoch: 492, Loss: 3.920
# Epoch: 493, Loss: 3.586
# Epoch: 494, Loss: 3.414
# Epoch: 495, Loss: 3.999
# Epoch: 496, Loss: 3.392
# Epoch: 497, Loss: 3.466
# Epoch: 498, Loss: 3.671
# Epoch: 499, Loss: 3.635
# Epoch: 500, Loss: 3.931
# Epoch: 501, Loss: 3.116
# Epoch: 502, Loss: 3.344
# Epoch: 503, Loss: 3.600
# Epoch: 504, Loss: 3.152
# Epoch: 505, Loss: 3.333
# Epoch: 506, Loss: 3.889
# Epoch: 507, Loss: 3.172
# Epoch: 508, Loss: 3.283
# Epoch: 509, Loss: 3.299
# Epoch: 510, Loss: 3.347
# Epoch: 511, Loss: 3.292
# Epoch: 512, Loss: 3.231
# Epoch: 513, Loss: 3.424
# Epoch: 514, Loss: 3.418
# Epoch: 515, Loss: 3.352
# Epoch: 516, Loss: 4.175
# Epoch: 517, Loss: 3.336
# Epoch: 518, Loss: 3.153
# Epoch: 519, Loss: 3.291
# Epoch: 520, Loss: 3.224
# Epoch: 521, Loss: 3.632
# Epoch: 522, Loss: 3.344
# Epoch: 523, Loss: 3.891
# Epoch: 524, Loss: 3.411
# Epoch: 525, Loss: 3.259
# Epoch: 526, Loss: 3.574
# Epoch: 527, Loss: 3.068
# Epoch: 528, Loss: 4.029
# Epoch: 529, Loss: 3.558
# Epoch: 530, Loss: 3.626
# Epoch: 531, Loss: 3.829
# Epoch: 532, Loss: 3.308
# Epoch: 533, Loss: 3.252
# Epoch: 534, Loss: 3.489
# Epoch: 535, Loss: 3.009
# Epoch: 536, Loss: 3.602
# Epoch: 537, Loss: 3.275
# Epoch: 538, Loss: 3.737
# Epoch: 539, Loss: 3.505
# Epoch: 540, Loss: 3.302
# Epoch: 541, Loss: 3.468
# Epoch: 542, Loss: 3.912
# Epoch: 543, Loss: 3.468
# Epoch: 544, Loss: 3.973
# Epoch: 545, Loss: 3.529
# Epoch: 546, Loss: 3.757
# Epoch: 547, Loss: 3.458
# Epoch: 548, Loss: 3.270
# Epoch: 549, Loss: 2.937
# Epoch: 550, Loss: 3.618
# Epoch: 551, Loss: 3.079
# Epoch: 552, Loss: 3.596
# Epoch: 553, Loss: 3.997
# Epoch: 554, Loss: 3.376
# Epoch: 555, Loss: 3.850
# Epoch: 556, Loss: 3.436
# Epoch: 557, Loss: 3.523
# Epoch: 558, Loss: 3.740
# Epoch: 559, Loss: 2.812
# Epoch: 560, Loss: 3.087
# Epoch: 561, Loss: 3.357
# Epoch: 562, Loss: 3.521
# Epoch: 563, Loss: 3.957
# Epoch: 564, Loss: 3.204
# Epoch: 565, Loss: 3.362
# Epoch: 566, Loss: 3.325
# Epoch: 567, Loss: 3.340
# Epoch: 568, Loss: 3.892
# Epoch: 569, Loss: 3.375
# Epoch: 570, Loss: 3.003
# Epoch: 571, Loss: 3.522
# Epoch: 572, Loss: 3.619
# Epoch: 573, Loss: 3.580
# Epoch: 574, Loss: 3.103
# Epoch: 575, Loss: 3.122
# Epoch: 576, Loss: 3.516
# Epoch: 577, Loss: 3.235
# Epoch: 578, Loss: 4.107
# Epoch: 579, Loss: 3.320
# Epoch: 580, Loss: 3.628
# Epoch: 581, Loss: 3.223
# Epoch: 582, Loss: 3.180
# Epoch: 583, Loss: 3.848
# Epoch: 584, Loss: 3.673
# Epoch: 585, Loss: 3.236
# Epoch: 586, Loss: 3.539
# Epoch: 587, Loss: 3.785
# Epoch: 588, Loss: 3.462
# Epoch: 589, Loss: 3.282
# Epoch: 590, Loss: 3.370
# Epoch: 591, Loss: 4.029
# Epoch: 592, Loss: 3.357
# Epoch: 593, Loss: 3.689
# Epoch: 594, Loss: 3.565
# Epoch: 595, Loss: 3.216
# Epoch: 596, Loss: 3.578
# Epoch: 597, Loss: 3.901
# Epoch: 598, Loss: 3.241
# Epoch: 599, Loss: 2.991
# Epoch: 600, Loss: 3.525
# Epoch: 601, Loss: 3.237
# Epoch: 602, Loss: 2.942
# Epoch: 603, Loss: 3.196
# Epoch: 604, Loss: 3.222
# Epoch: 605, Loss: 3.173
# Epoch: 606, Loss: 3.420
# Epoch: 607, Loss: 3.278
# Epoch: 608, Loss: 3.697
# Epoch: 609, Loss: 3.048
# Epoch: 610, Loss: 3.325
# Epoch: 611, Loss: 3.529
# Epoch: 612, Loss: 3.555
# Epoch: 613, Loss: 3.422
# Epoch: 614, Loss: 3.456
# Epoch: 615, Loss: 2.935
# Epoch: 616, Loss: 3.607
# Epoch: 617, Loss: 3.175
# Epoch: 618, Loss: 3.503
# Epoch: 619, Loss: 3.492
# Epoch: 620, Loss: 3.910
# Epoch: 621, Loss: 2.963
# Epoch: 622, Loss: 3.696
# Epoch: 623, Loss: 3.017
# Epoch: 624, Loss: 3.443
# Epoch: 625, Loss: 3.382
# Epoch: 626, Loss: 3.511
# Epoch: 627, Loss: 3.838
# Epoch: 628, Loss: 3.249
# Epoch: 629, Loss: 3.155
# Epoch: 630, Loss: 3.146
# Epoch: 631, Loss: 3.404
# Epoch: 632, Loss: 3.514
# Epoch: 633, Loss: 3.153
# Epoch: 634, Loss: 3.225
# Epoch: 635, Loss: 3.513
# Epoch: 636, Loss: 3.474
# Epoch: 637, Loss: 3.841
# Epoch: 638, Loss: 3.480
# Epoch: 639, Loss: 3.169
# Epoch: 640, Loss: 3.302
# Epoch: 641, Loss: 3.389
# Epoch: 642, Loss: 3.504
# Epoch: 643, Loss: 3.365
# Epoch: 644, Loss: 3.180
# Epoch: 645, Loss: 3.132
# Epoch: 646, Loss: 3.420
# Epoch: 647, Loss: 3.097
# Epoch: 648, Loss: 3.829
# Epoch: 649, Loss: 3.693
# Epoch: 650, Loss: 3.237
# Epoch: 651, Loss: 3.503
# Epoch: 652, Loss: 3.817
# Epoch: 653, Loss: 3.171
# Epoch: 654, Loss: 3.207
# Epoch: 655, Loss: 3.641
# Epoch: 656, Loss: 3.269
# Epoch: 657, Loss: 3.422
# Epoch: 658, Loss: 3.537
# Epoch: 659, Loss: 3.307
# Epoch: 660, Loss: 3.146
# Epoch: 661, Loss: 3.298
# Epoch: 662, Loss: 3.560
# Epoch: 663, Loss: 3.512
# Epoch: 664, Loss: 3.451
# Epoch: 665, Loss: 3.485
# Epoch: 666, Loss: 3.146
# Epoch: 667, Loss: 2.928
# Epoch: 668, Loss: 3.918
# Epoch: 669, Loss: 3.461
# Epoch: 670, Loss: 3.047
# Epoch: 671, Loss: 2.861
# Epoch: 672, Loss: 3.461
# Epoch: 673, Loss: 3.475
# Epoch: 674, Loss: 3.409
# Epoch: 675, Loss: 3.287
# Epoch: 676, Loss: 3.322
# Epoch: 677, Loss: 3.390
# Epoch: 678, Loss: 3.240
# Epoch: 679, Loss: 3.299
# Epoch: 680, Loss: 3.337
# Epoch: 681, Loss: 3.103
# Epoch: 682, Loss: 2.871
# Epoch: 683, Loss: 3.150
# Epoch: 684, Loss: 3.233
# Epoch: 685, Loss: 3.497
# Epoch: 686, Loss: 3.173
# Epoch: 687, Loss: 3.203
# Epoch: 688, Loss: 3.068
# Epoch: 689, Loss: 3.357
# Epoch: 690, Loss: 3.957
# Epoch: 691, Loss: 3.567
# Epoch: 692, Loss: 3.282
# Epoch: 693, Loss: 3.160
# Epoch: 694, Loss: 3.361
# Epoch: 695, Loss: 2.909
# Epoch: 696, Loss: 3.336
# Epoch: 697, Loss: 3.493
# Epoch: 698, Loss: 3.581
# Epoch: 699, Loss: 3.015
# Epoch: 700, Loss: 3.526
# Epoch: 701, Loss: 3.579
# Epoch: 702, Loss: 3.536
# Epoch: 703, Loss: 3.072
# Epoch: 704, Loss: 3.687
# Epoch: 705, Loss: 3.642
# Epoch: 706, Loss: 3.239
# Epoch: 707, Loss: 3.083
# Epoch: 708, Loss: 3.401
# Epoch: 709, Loss: 3.007
# Epoch: 710, Loss: 3.561
# Epoch: 711, Loss: 3.657
# Epoch: 712, Loss: 3.479
# Epoch: 713, Loss: 3.421
# Epoch: 714, Loss: 3.480
# Epoch: 715, Loss: 3.755
# Epoch: 716, Loss: 3.015
# Epoch: 717, Loss: 3.314
# Epoch: 718, Loss: 3.514
# Epoch: 719, Loss: 3.273
# Epoch: 720, Loss: 3.284
# Epoch: 721, Loss: 3.474
# Epoch: 722, Loss: 3.127
# Epoch: 723, Loss: 3.074
# Epoch: 724, Loss: 3.386
# Epoch: 725, Loss: 3.390
# Epoch: 726, Loss: 3.591
# Epoch: 727, Loss: 3.310
# Epoch: 728, Loss: 3.281
# Epoch: 729, Loss: 3.778
# Epoch: 730, Loss: 3.160
# Epoch: 731, Loss: 3.459
# Epoch: 732, Loss: 3.563
# Epoch: 733, Loss: 3.481
# Epoch: 734, Loss: 3.370
# Epoch: 735, Loss: 3.606
# Epoch: 736, Loss: 3.286
# Epoch: 737, Loss: 3.477
# Epoch: 738, Loss: 3.103
# Epoch: 739, Loss: 3.122
# Epoch: 740, Loss: 3.045
# Epoch: 741, Loss: 2.878
# Epoch: 742, Loss: 2.993
# Epoch: 743, Loss: 3.606
# Epoch: 744, Loss: 3.534
# Epoch: 745, Loss: 3.598
# Epoch: 746, Loss: 3.401
# Epoch: 747, Loss: 3.020
# Epoch: 748, Loss: 3.310
# Epoch: 749, Loss: 3.456
# Epoch: 750, Loss: 3.399
# Epoch: 751, Loss: 3.070
# Epoch: 752, Loss: 3.403
# Epoch: 753, Loss: 3.484
# Epoch: 754, Loss: 3.265
# Epoch: 755, Loss: 3.772
# Epoch: 756, Loss: 3.221
# Epoch: 757, Loss: 3.335
# Epoch: 758, Loss: 3.418
# Epoch: 759, Loss: 2.940
# Epoch: 760, Loss: 3.650
# Epoch: 761, Loss: 2.737
# Epoch: 762, Loss: 4.037
# Epoch: 763, Loss: 3.105
# Epoch: 764, Loss: 2.979
# Epoch: 765, Loss: 3.655
# Epoch: 766, Loss: 3.162
# Epoch: 767, Loss: 3.231
# Epoch: 768, Loss: 3.417
# Epoch: 769, Loss: 3.715
# Epoch: 770, Loss: 3.486
# Epoch: 771, Loss: 3.538
# Epoch: 772, Loss: 3.379
# Epoch: 773, Loss: 3.198
# Epoch: 774, Loss: 3.363
# Epoch: 775, Loss: 2.990
# Epoch: 776, Loss: 3.647
# Epoch: 777, Loss: 3.379
# Epoch: 778, Loss: 3.269
# Epoch: 779, Loss: 2.944
# Epoch: 780, Loss: 3.059
# Epoch: 781, Loss: 3.360
# Epoch: 782, Loss: 2.977
# Epoch: 783, Loss: 3.611
# Epoch: 784, Loss: 3.544
# Epoch: 785, Loss: 3.721
# Epoch: 786, Loss: 3.656
# Epoch: 787, Loss: 3.528
# Epoch: 788, Loss: 3.296
# Epoch: 789, Loss: 3.088
# Epoch: 790, Loss: 3.640
# Epoch: 791, Loss: 3.337
# Epoch: 792, Loss: 3.479
# Epoch: 793, Loss: 2.777
# Epoch: 794, Loss: 3.403
# Epoch: 795, Loss: 3.651
# Epoch: 796, Loss: 3.695
# Epoch: 797, Loss: 3.360
# Epoch: 798, Loss: 3.428
# Epoch: 799, Loss: 3.254
# Epoch: 800, Loss: 2.777
# Epoch: 801, Loss: 3.253
# Epoch: 802, Loss: 3.507
# Epoch: 803, Loss: 3.485
# Epoch: 804, Loss: 2.861
# Epoch: 805, Loss: 3.266
# Epoch: 806, Loss: 3.609
# Epoch: 807, Loss: 3.474
# Epoch: 808, Loss: 4.039
# Epoch: 809, Loss: 3.083
# Epoch: 810, Loss: 3.284
# Epoch: 811, Loss: 3.088
# Epoch: 812, Loss: 3.224
# Epoch: 813, Loss: 3.083
# Epoch: 814, Loss: 3.309
# Epoch: 815, Loss: 3.692
# Epoch: 816, Loss: 3.265
# Epoch: 817, Loss: 3.257
# Epoch: 818, Loss: 3.647
# Epoch: 819, Loss: 3.070
# Epoch: 820, Loss: 2.765
# Epoch: 821, Loss: 3.109
# Epoch: 822, Loss: 3.339
# Epoch: 823, Loss: 3.221
# Epoch: 824, Loss: 3.027
# Epoch: 825, Loss: 3.467
# Epoch: 826, Loss: 3.291
# Epoch: 827, Loss: 3.693
# Epoch: 828, Loss: 3.328
# Epoch: 829, Loss: 3.050
# Epoch: 830, Loss: 3.424
# Epoch: 831, Loss: 3.751
# Epoch: 832, Loss: 3.194
# Epoch: 833, Loss: 3.268
# Epoch: 834, Loss: 3.503
# Epoch: 835, Loss: 3.283
# Epoch: 836, Loss: 3.785
# Epoch: 837, Loss: 3.259
# Epoch: 838, Loss: 3.153
# Epoch: 839, Loss: 3.228
# Epoch: 840, Loss: 4.187
# Epoch: 841, Loss: 3.343
# Epoch: 842, Loss: 3.056
# Epoch: 843, Loss: 3.892
# Epoch: 844, Loss: 3.401
# Epoch: 845, Loss: 3.288
# Epoch: 846, Loss: 3.291
# Epoch: 847, Loss: 3.432
# Epoch: 848, Loss: 3.249
# Epoch: 849, Loss: 3.373
# Epoch: 850, Loss: 3.281
# Epoch: 851, Loss: 3.089
# Epoch: 852, Loss: 3.559
# Epoch: 853, Loss: 3.266
# Epoch: 854, Loss: 3.566
# Epoch: 855, Loss: 3.259
# Epoch: 856, Loss: 3.308
# Epoch: 857, Loss: 2.859
# Epoch: 858, Loss: 3.558
# Epoch: 859, Loss: 3.241
# Epoch: 860, Loss: 2.902
# Epoch: 861, Loss: 3.247
# Epoch: 862, Loss: 3.512
# Epoch: 863, Loss: 3.737
# Epoch: 864, Loss: 3.190
# Epoch: 865, Loss: 3.407
# Epoch: 866, Loss: 3.826
# Epoch: 867, Loss: 3.323
# Epoch: 868, Loss: 3.263
# Epoch: 869, Loss: 3.832
# Epoch: 870, Loss: 3.715
# Epoch: 871, Loss: 2.909
# Epoch: 872, Loss: 3.191
# Epoch: 873, Loss: 2.857
# Epoch: 874, Loss: 3.416
# Epoch: 875, Loss: 3.466
# Epoch: 876, Loss: 3.091
# Epoch: 877, Loss: 3.493
# Epoch: 878, Loss: 3.052
# Epoch: 879, Loss: 3.623
# Epoch: 880, Loss: 3.268
# Epoch: 881, Loss: 3.019
# Epoch: 882, Loss: 3.069
# Epoch: 883, Loss: 3.490
# Epoch: 884, Loss: 3.425
# Epoch: 885, Loss: 3.325
# Epoch: 886, Loss: 3.210
# Epoch: 887, Loss: 3.254
# Epoch: 888, Loss: 3.330
# Epoch: 889, Loss: 3.232
# Epoch: 890, Loss: 3.206
# Epoch: 891, Loss: 2.945
# Epoch: 892, Loss: 2.800
# Epoch: 893, Loss: 3.061
# Epoch: 894, Loss: 3.354
# Epoch: 895, Loss: 3.841
# Epoch: 896, Loss: 3.038
# Epoch: 897, Loss: 3.343
# Epoch: 898, Loss: 3.589
# Epoch: 899, Loss: 3.506
# Epoch: 900, Loss: 2.954
# Epoch: 901, Loss: 3.768
# Epoch: 902, Loss: 3.336
# Epoch: 903, Loss: 3.715
# Epoch: 904, Loss: 3.796
# Epoch: 905, Loss: 3.100
# Epoch: 906, Loss: 3.511
# Epoch: 907, Loss: 3.434
# Epoch: 908, Loss: 3.157
# Epoch: 909, Loss: 2.973
# Epoch: 910, Loss: 3.236
# Epoch: 911, Loss: 3.231
# Epoch: 912, Loss: 3.726
# Epoch: 913, Loss: 3.473
# Epoch: 914, Loss: 2.837
# Epoch: 915, Loss: 2.478
# Epoch: 916, Loss: 3.577
# Epoch: 917, Loss: 2.937
# Epoch: 918, Loss: 3.136
# Epoch: 919, Loss: 2.958
# Epoch: 920, Loss: 3.656
# Epoch: 921, Loss: 3.255
# Epoch: 922, Loss: 3.285
# Epoch: 923, Loss: 3.469
# Epoch: 924, Loss: 3.724
# Epoch: 925, Loss: 3.236
# Epoch: 926, Loss: 3.309
# Epoch: 927, Loss: 2.991
# Epoch: 928, Loss: 3.867
# Epoch: 929, Loss: 3.390
# Epoch: 930, Loss: 3.048
# Epoch: 931, Loss: 3.293
# Epoch: 932, Loss: 3.395
# Epoch: 933, Loss: 3.026
# Epoch: 934, Loss: 3.135
# Epoch: 935, Loss: 2.761
# Epoch: 936, Loss: 3.334
# Epoch: 937, Loss: 3.350
# Epoch: 938, Loss: 3.871
# Epoch: 939, Loss: 2.785
# Epoch: 940, Loss: 3.228
# Epoch: 941, Loss: 3.236
# Epoch: 942, Loss: 3.328
# Epoch: 943, Loss: 3.140
# Epoch: 944, Loss: 3.031
# Epoch: 945, Loss: 3.216
# Epoch: 946, Loss: 3.331
# Epoch: 947, Loss: 3.786
# Epoch: 948, Loss: 3.374
# Epoch: 949, Loss: 3.783
# Epoch: 950, Loss: 3.192
# Epoch: 951, Loss: 3.621
# Epoch: 952, Loss: 3.543
# Epoch: 953, Loss: 3.871
# Epoch: 954, Loss: 3.105
# Epoch: 955, Loss: 3.647
# Epoch: 956, Loss: 3.589
# Epoch: 957, Loss: 3.322
# Epoch: 958, Loss: 2.938
# Epoch: 959, Loss: 3.136
# Epoch: 960, Loss: 3.417
# Epoch: 961, Loss: 3.600
# Epoch: 962, Loss: 2.915
# Epoch: 963, Loss: 3.021
# Epoch: 964, Loss: 3.589
# Epoch: 965, Loss: 3.142
# Epoch: 966, Loss: 3.258
# Epoch: 967, Loss: 3.222
# Epoch: 968, Loss: 3.216
# Epoch: 969, Loss: 3.519
# Epoch: 970, Loss: 3.301
# Epoch: 971, Loss: 3.108
# Epoch: 972, Loss: 3.171
# Epoch: 973, Loss: 3.062
# Epoch: 974, Loss: 3.164
# Epoch: 975, Loss: 3.132
# Epoch: 976, Loss: 3.089
# Epoch: 977, Loss: 3.339
# Epoch: 978, Loss: 3.049
# Epoch: 979, Loss: 3.330
# Epoch: 980, Loss: 3.265
# Epoch: 981, Loss: 3.508
# Epoch: 982, Loss: 3.267
# Epoch: 983, Loss: 3.171
# Epoch: 984, Loss: 3.036
# Epoch: 985, Loss: 3.814
# Epoch: 986, Loss: 3.434
# Epoch: 987, Loss: 3.443
# Epoch: 988, Loss: 3.664
# Epoch: 989, Loss: 3.429
# Epoch: 990, Loss: 3.092
# Epoch: 991, Loss: 3.290
# Epoch: 992, Loss: 3.397
# Epoch: 993, Loss: 3.138
# Epoch: 994, Loss: 3.372
# Epoch: 995, Loss: 3.214
# Epoch: 996, Loss: 3.098
# Epoch: 997, Loss: 3.490
# Epoch: 998, Loss: 3.155
# Epoch: 999, Loss: 3.190
# Epoch: 1000, Loss: 3.687
